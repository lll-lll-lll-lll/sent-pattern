# %%
import spacy
from spacy import displacy

# %%
nlp = spacy.load("en_core_web_lg")

# %%
text_1 = "The firm obtained that information without users' consent from a researcher who had been allowed by Facebook to deploy an app on the platform which harvested data from millions of its users."
doc = nlp(text_1)

displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f868cf2ab5e94341b2e3e0c7decba732-0" class="displacy" width="5650" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">firm</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
# ...

# %%
text_1 = "A recent report published by JP Morgan suggested that Apple is looking to shift 25% of its iPhone production to India by 2025."
doc = nlp(text_1)

for token in doc:
    # print(token, token.dep_)
    if token.dep_ == "ROOT":
        for child in token.children:
            if child.dep_ == "ccomp":
                for a in child.subtree:
                    print(a)
# Out:
# that
# Apple
# is
# looking
# to
# shift
# 25
# %
# of
# its
# iPhone
# production
# to
# India
# by
# 2025
