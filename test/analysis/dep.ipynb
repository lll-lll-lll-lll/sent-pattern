# %%
import spacy
from spacy import displacy

# %%
nlp = spacy.load("en_core_web_lg")

# %%
text_1 = "In this quickstart we’ll create a development shell with specific tools installed. "
doc = nlp(text_1)

displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="3c2f59e54d22443483d29e5521773956-0" class="displacy" width="2325" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
# ...

# %%
text_1 = "A recent report published by JP Morgan suggested that Apple is looking to shift 25% of its iPhone production to India by 2025."
doc = nlp(text_1)

for token in doc:
    # print(token, token.dep_)
    if token.dep_ == "ROOT":
        for child in token.children:
            if child.dep_ == "ccomp":
                for a in child.subtree:
                    print(a)
# Out:
# that
# Apple
# is
# looking
# to
# shift
# 25
# %
# of
# its
# iPhone
# production
# to
# India
# by
# 2025
